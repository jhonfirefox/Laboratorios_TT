# %% [markdown]
# <a href="https://colab.research.google.com/github/jhonfirefox/Laboratorios_TT/blob/main/Lab9_TT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/jhonfirefox/Laboratorios_TT

# %%
#Se importan las librerias necesarias para los codigos
import pandas as pd
import numpy as np
from cryptography.fernet import Fernet
import datetime

# %%
#Definimos algunas funciones que se utilizaran con frecuencia
def validacionDatos_Numerico(datos, campo):
  datos['Validacion_'+campo] = datos[campo].apply(lambda x:'Válido' if (pd.notnull(x) and (isinstance(x, int) or isinstance(x, float))) else 'Inválido')

#Funcion para validar que los datos sean no negativos
def validacionDatos_Numerico_NN(datos, campo):
  datos['Validacion_NN_'+campo] = datos[campo].apply(lambda x:'Válido' if (pd.notnull(x) and (isinstance(x, int) or isinstance(x, float)) and x >= 0) else 'Inválido')

def valoresFaltantes(datos):
    return datos.isnull().sum()

##Corregimos la fecha de los registros que estan en formato "%Y/%m/%d"
def corregir_fecha(fecha_str, formato):
    try:
        fecha = datetime.datetime.strptime(fecha_str, formato)
        return fecha.strftime("%Y-%m-%d")
    except ValueError:
        return fecha_str

def validarFecha(fecha_str, formato):
    try:
        fecha = datetime.datetime.strptime(fecha_str, formato)
        return "Válido"
    except ValueError:
        return "Inválido"
def eliminarFechasNulas(datos, campo):
  for indice, fecha in enumerate(datos[campo]):
    if pd.isnull(fecha):
      datos = datos.drop(indice)
  return datos

#Validamos que el campo de la fecha se encuentre correcto
def validacionDatos_Fecha(datos, campo, formatoFecha):
   #datos['Validacion'+campo] = datos[campo].apply(lambda x:'Válido' if isinstance(datetime.datetime.strptime(x, "%Y/%m/%d"), datetime.datetime) else 'Inválido')
   datos['Validacion_'+campo] = datos[campo].apply(validarFecha, args=(formatoFecha,))

# %% [markdown]
# # **Parte 1**
#
# El primer ejercicio de práctica deberás realizar el código usando las bibliotecas en Python para la manipulación de los datos y aplicar la calidad de los datos, pegar la captura de pantalla del resultado y copiar el código según el caso.

# %% [markdown]
# #**1. Ejercicio de práctica 1.**
#
# Aseguramiento de la Calidad de los Datos
#
# 1. Se tiene un conjunto de datos sobre empleados que incluye su nombre, edad, salario y fecha de ingreso. Se requiere implementar algunos pasos de aseguramiento de la calidad de los datos, como la verificación de valores faltantes y la validación de formatos de datos.
#
# Datos
#
# •
# Nombre: Juan,Ana, Pedro,María,Luis,Ana
# •
# Edad:28, 34, None, 45, 38, 34.
# •
# Salario:3000, 4000, cinco mil, 4500, 4000, 5000
# •
# Fecha Ingreso:2021-01-15, 2020/03/12, 2022-07-01,2021/12/01,2021-05-20, 2020-03-12
#
#
# Se requiere:
# 1. Identificar y contar los valores faltantes en cada columna.
# 2. Verificar el formato de la columna 'Salario' para asegurar que todos los valores sean numéricos.
# 3. Validar y estandarizar el formato de la columna 'Fecha Ingreso' a YYYY-MM-DD.

# %%
#Generamos las listas con los vectores
datos1 = {"Nombre" : ["Juan","Ana", "Pedro","María","Luis","Ana"], "Edad" : [28, 34, None, 45, 38, 34], "Salario": [3000, 4000, "cinco mil", 4500, 4000, 5000],"Fecha Ingreso":["2021-01-15", "2020/03/12", "2022-07-01","2021/12/01","2021-05-20", "2020-03-12"]}
#print(datos1)

for key in datos1.keys():
    print(key, ":", datos1[key])
# Out:
# Nombre : ['Juan', 'Ana', 'Pedro', 'María', 'Luis', 'Ana']
# Edad : [28, 34, None, 45, 38, 34]
# Salario : [3000, 4000, 'cinco mil', 4500, 4000, 5000]
# Fecha Ingreso : ['2021-01-15', '2020/03/12', '2022-07-01', '2021/12/01', '2021-05-20', '2020-03-12']

# %%
#Identificar y contar los valores faltantes en cada columna.
#creamos el dataframe asociado a los datos
datos1_df = pd.DataFrame(datos1)
datos1_df
# Out:
#   Nombre  Edad    Salario Fecha Ingreso
# 0   Juan  28.0       3000    2021-01-15
# 1    Ana  34.0       4000    2020/03/12
# 2  Pedro   NaN  cinco mil    2022-07-01
# 3  María  45.0       4500    2021/12/01
# 4   Luis  38.0       4000    2021-05-20
# 5    Ana  34.0       5000    2020-03-12

# %%
#Verficamos si hay datos nulos
#datos1_df['ValidacionEdad'] = datos1_df['Edad'].apply(lambda x:'Válido' if pd.notnull(x) and x >= 0 else 'Inválido')
validacionDatos_Numerico(datos1_df, 'Edad')
datos1_df
# Out:
#   Nombre  Edad    Salario Fecha Ingreso Validacion_Edad
# 0   Juan  28.0       3000    2021-01-15          Válido
# 1    Ana  34.0       4000    2020/03/12          Válido
# 2  Pedro   NaN  cinco mil    2022-07-01        Inválido
# 3  María  45.0       4500    2021/12/01          Válido
# 4   Luis  38.0       4000    2021-05-20          Válido
# 5    Ana  34.0       5000    2020-03-12          Válido

# %%
#valores_Faltantes = datos1_df.isnull().sum()
valores_Faltantes = valoresFaltantes(datos1_df)
print(valores_Faltantes)

if valores_Faltantes.any():
    print("Hay valores faltantes en el DataFrame.")
else:
    print("No hay valores faltantes en el DataFrame.")
# Out:
# Nombre             0
# Edad               1
# Salario            0
# Fecha Ingreso      0
# Validacion_Edad    0
# dtype: int64
# Hay valores faltantes en el DataFrame.

# %%
#Verificar el formato de la columna 'Salario' para asegurar que todos los valores sean numéricos.
#datos1_df['ValidacionSalario'] = datos1_df['Salario'].apply(lambda x: 'Válido' if pd.notnull(x) and str(x).isdigit() else 'Inválido')
validacionDatos_Numerico(datos1_df, 'Salario')
print(datos1_df)

for i in datos1_df.Salario:
    if not(str(i).isdigit()):
        print("El valor (", i, ") de Salario no es valor numerico")
# Out:
#   Nombre  Edad    Salario Fecha Ingreso Validacion_Edad Validacion_Salario
# 0   Juan  28.0       3000    2021-01-15          Válido             Válido
# 1    Ana  34.0       4000    2020/03/12          Válido             Válido
# 2  Pedro   NaN  cinco mil    2022-07-01        Inválido           Inválido
# 3  María  45.0       4500    2021/12/01          Válido             Válido
# 4   Luis  38.0       4000    2021-05-20          Válido             Válido
# 5    Ana  34.0       5000    2020-03-12          Válido             Válido
# El valor ( cinco mil ) de Salario no es valor numerico

# %%
#Convertimos el valor no numerico a numerico del campo salario
datos1_df.loc[2,'Salario'] = 5000
datos1_df
# Out:
#   Nombre  Edad Salario Fecha Ingreso Validacion_Edad Validacion_Salario  \
# 0   Juan  28.0    3000    2021-01-15          Válido             Válido
# 1    Ana  34.0    4000    2020/03/12          Válido             Válido
# 2  Pedro   NaN    5000    2022-07-01        Inválido           Inválido
# 3  María  45.0    4500    2021/12/01          Válido             Válido
# 4   Luis  38.0    4000    2021-05-20          Válido             Válido
# 5    Ana  34.0    5000    2020-03-12          Válido             Válido
#
#   FechaIngreso
# 0   2021-01-15
# 1          NaT
# 2   2022-07-01
# 3          NaT
# 4   2021-05-20
# 5   2020-03-12

# %%
#Validar el formato de la columna 'Fecha Ingreso' a YYYY-MM-DD.
#datos1_df['FechaIngreso'] = pd.to_datetime(datos1_df['Fecha Ingreso'], errors='coerce', format='%Y-%m-%d')
validacionDatos_Fecha(datos1_df, "Fecha Ingreso", "%Y-%m-%d")

print("\nDatos después de Validar 'FechaIngreso':")
datos1_df
# Out:
# Datos después de Validar 'FechaIngreso':
#   Nombre  Edad Salario Fecha Ingreso Validacion_Edad Validacion_Salario  \
# 0   Juan  28.0    3000    2021-01-15          Válido             Válido
# 1    Ana  34.0    4000    2020/03/12          Válido             Válido
# 2  Pedro   NaN    5000    2022-07-01        Inválido           Inválido
# 3  María  45.0    4500    2021/12/01          Válido             Válido
# 4   Luis  38.0    4000    2021-05-20          Válido             Válido
# 5    Ana  34.0    5000    2020-03-12          Válido             Válido
#
#   FechaIngreso Validacion_Fecha Ingreso
# 0   2021-01-15                   Válido
# 1          NaT                 Inválido
# 2   2022-07-01                   Válido
# 3          NaT                 Inválido
# 4   2021-05-20                   Válido
# 5   2020-03-12                   Válido

# %%
##Corregimos la fecha de los registros que estan en formato "%Y/%m/%d"

datos1_df['Fecha Ingreso'] = datos1_df['Fecha Ingreso'].apply(corregir_fecha, args=("%Y/%m/%d",))
datos1_df
#
# Out:
#   Nombre  Edad Salario Fecha Ingreso Validacion_Edad Validacion_Salario  \
# 0   Juan  28.0    3000    2021-01-15          Válido             Válido
# 1    Ana  34.0    4000    2020-03-12          Válido             Válido
# 2  Pedro   NaN    5000    2022-07-01        Inválido           Inválido
# 3  María  45.0    4500    2021-12-01          Válido             Válido
# 4   Luis  38.0    4000    2021-05-20          Válido             Válido
# 5    Ana  34.0    5000    2020-03-12          Válido             Válido
#
#   FechaIngreso Validacion_Fecha Ingreso
# 0   2021-01-15                   Válido
# 1          NaT                 Inválido
# 2   2022-07-01                   Válido
# 3          NaT                 Inválido
# 4   2021-05-20                   Válido
# 5   2020-03-12                   Válido

# %%
#Validamos de nuevo la fecha
validacionDatos_Fecha(datos1_df, "Fecha Ingreso", "%Y-%m-%d")
datos1_df
# Out:
#   Nombre  Edad Salario Fecha Ingreso Validacion_Edad Validacion_Salario  \
# 0   Juan  28.0    3000    2021-01-15          Válido             Válido
# 1    Ana  34.0    4000    2020-03-12          Válido             Válido
# 2  Pedro   NaN    5000    2022-07-01        Inválido           Inválido
# 3  María  45.0    4500    2021-12-01          Válido             Válido
# 4   Luis  38.0    4000    2021-05-20          Válido             Válido
# 5    Ana  34.0    5000    2020-03-12          Válido             Válido
#
#   FechaIngreso Validacion_Fecha Ingreso
# 0   2021-01-15                   Válido
# 1          NaT                   Válido
# 2   2022-07-01                   Válido
# 3          NaT                   Válido
# 4   2021-05-20                   Válido
# 5   2020-03-12                   Válido

# %% [markdown]
# 2. Se tiene un conjunto de datos sobre empleados que incluye su nombre, edad, salario, puesto de trabajo y fecha de ingreso. Se requiere implementar aseguramiento de la calidad de los datos, verificando la completitud de los datos, la validez de los salarios y la consistencia de las fechas de ingreso.
#
# Datos: Nombre: Juan, Ana, Pedro, María, Luis, Carla
# Edad: 28, None, 40, 45, 38, 34
# Salario: 3000, 4000, 4500, cuatro mil, 5000, 4000
# Cargo: Analista, Gerente, Desarrollador, Gerente, Analista, None
# Fecha Ingreso: 2021-01-15, 2020/03/12, 2022-07-01, 2021/12/01, None, 2020-03-12

# %% [markdown]
# Se requiere:
# 1. Identificar y contar los valores faltantes en cada columna.
# 2. Verificar el formato de la columna "Salario" para asegurarse de que todos los valores sean numéricos.
# 3. Validar y estandarizar el formato de la columna "FechaIngreso" a YYYY-MM-DD.
# 4. Verificar que no haya valores faltantes en la columna "Cargo".

# %%
#Generamos las listas con los vectores
datos2 = {"Nombre" : ["Juan", "Ana", "Pedro", "María", "Luis", "Carla"], "Edad" : [28, None, 40, 45, 38, 34], "Salario": [3000, 4000, 4500, "cuatro mil", 5000, 4000],
"cargo":["Analista", "Gerente", "Desarrollador", "Gerente", "Analista", None],
"Fecha Ingreso":["2021-01-15", "2020/03/12", "2022-07-01", "2021/12/01", None, "2020-03-12"]}

datos2_df = pd.DataFrame(datos2)

for key in datos2.keys():
    print(key, ":", datos2[key])
# Out:
# Nombre : ['Juan', 'Ana', 'Pedro', 'María', 'Luis', 'Carla']
# Edad : [28, None, 40, 45, 38, 34]
# Salario : [3000, 4000, 4500, 'cuatro mil', 5000, 4000]
# cargo : ['Analista', 'Gerente', 'Desarrollador', 'Gerente', 'Analista', None]
# Fecha Ingreso : ['2021-01-15', '2020/03/12', '2022-07-01', '2021/12/01', None, '2020-03-12']

# %%
#Identificar y contar los valores faltantes en cada columna.
#valores_faltantes = datos2_df.isnull().sum()
valores_faltantes = valoresFaltantes(datos2_df)

print(valores_faltantes)

if valores_faltantes.any():
    print("Hay valores faltantes en el DataFrame.")
else:
    print("No hay valores faltantes en el DataFrame.")
# Out:
# Nombre           0
# Edad             1
# Salario          0
# cargo            1
# Fecha Ingreso    1
# dtype: int64
# Hay valores faltantes en el DataFrame.

# %%
#Verificar el formato de la columna "Salario" para asegurarse de que todos los valores sean numéricos.
#datos2_df['ValidacionSalario'] = datos2_df['Salario'].apply(lambda x: 'Válido' if pd.notnull(x) and str(x).isdigit() else 'Inválido')
validacionDatos_Numerico(datos2_df, 'Salario')
print(datos2_df)

for i in datos2_df.Salario:
    if not(str(i).isdigit()):
        print("El valor (", i, ") de Salario no es un valor numerico")
# Out:
#   Nombre  Edad     Salario          cargo Fecha Ingreso Validacion_Salario
# 0   Juan  28.0        3000       Analista    2021-01-15             Válido
# 1    Ana   NaN        4000        Gerente    2020/03/12             Válido
# 2  Pedro  40.0        4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0  cuatro mil        Gerente    2021/12/01           Inválido
# 4   Luis  38.0        5000       Analista          None             Válido
# 5  Carla  34.0        4000           None    2020-03-12             Válido
# El valor ( cuatro mil ) de Salario no es un valor numerico

# %%
#Convertimos el valor no numerico a numerico del campo salario
datos2_df.loc[3,'Salario'] = 4000
datos2_df
# Out:
#   Nombre  Edad Salario          cargo Fecha Ingreso Validacion_Salario
# 0   Juan  28.0    3000       Analista    2021-01-15             Válido
# 1    Ana   NaN    4000        Gerente    2020/03/12             Válido
# 2  Pedro  40.0    4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0    4000        Gerente    2021/12/01           Inválido
# 4   Luis  38.0    5000       Analista          None             Válido
# 5  Carla  34.0    4000           None    2020-03-12             Válido

# %%
#Validamos de nuevo el salario
validacionDatos_Numerico(datos2_df, 'Salario')
print(datos2_df)
# Out:
#   Nombre  Edad Salario          cargo Fecha Ingreso Validacion_Salario
# 0   Juan  28.0    3000       Analista    2021-01-15             Válido
# 1    Ana   NaN    4000        Gerente    2020/03/12             Válido
# 2  Pedro  40.0    4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0    4000        Gerente    2021/12/01             Válido
# 4   Luis  38.0    5000       Analista          None             Válido
# 5  Carla  34.0    4000           None    2020-03-12             Válido

# %%
#Para validar el formato de fecha, debemos eliminar la fechas nulas
datos2_df = eliminarFechasNulas(datos2_df, 'Fecha Ingreso')
datos2_df
# Out:
#   Nombre  Edad Salario          cargo Fecha Ingreso Validacion_Salario
# 0   Juan  28.0    3000       Analista    2021-01-15             Válido
# 1    Ana   NaN    4000        Gerente    2020/03/12             Válido
# 2  Pedro  40.0    4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0    4000        Gerente    2021/12/01             Válido
# 5  Carla  34.0    4000           None    2020-03-12             Válido

# %%
#Validar el formato de la columna "FechaIngreso" a YYYY-MM-DD.
#datos2_df['FechaIngreso'] = pd.to_datetime(datos2_df['Fecha Ingreso'], errors='coerce', format='%Y-%m-%d')
validacionDatos_Fecha(datos2_df, "Fecha Ingreso", "%Y-%m-%d")

print("\nDatos después de validar 'Fecha Ingreso':")
datos2_df
# Out:
# Datos después de validar 'Fecha Ingreso':
#   Nombre  Edad Salario          cargo Fecha Ingreso Validacion_Salario  \
# 0   Juan  28.0    3000       Analista    2021-01-15             Válido
# 1    Ana   NaN    4000        Gerente    2020/03/12             Válido
# 2  Pedro  40.0    4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0    4000        Gerente    2021/12/01             Válido
# 5  Carla  34.0    4000           None    2020-03-12             Válido
#
#   Validacion_Fecha Ingreso
# 0                   Válido
# 1                 Inválido
# 2                   Válido
# 3                 Inválido
# 5                   Válido

# %%
datos2_df['Fecha Ingreso']
# Out:
# 0    2021-01-15
# 1    2020/03/12
# 2    2022-07-01
# 3    2021/12/01
# 5    2020-03-12
# Name: Fecha Ingreso, dtype: object

# %%
#Estandarizamos el formato de la columna "FechaIngreso" a YYYY-MM-DD.
#Estandarizamos la fecha
datos2_df['Fecha Ingreso'] = datos2_df['Fecha Ingreso'].apply(corregir_fecha, args=("%Y/%m/%d",))
datos2_df

#Validamos que el campo de fecha de ingreso este correcto
validacionDatos_Fecha(datos2_df, 'Fecha Ingreso',"%Y-%m-%d")
datos2_df
# Out:
#   Nombre  Edad Salario          cargo Fecha Ingreso Validacion_Salario  \
# 0   Juan  28.0    3000       Analista    2021-01-15             Válido
# 1    Ana   NaN    4000        Gerente    2020-03-12             Válido
# 2  Pedro  40.0    4500  Desarrollador    2022-07-01             Válido
# 3  María  45.0    4000        Gerente    2021-12-01             Válido
# 5  Carla  34.0    4000           None    2020-03-12             Válido
#
#   Validacion_Fecha Ingreso
# 0                   Válido
# 1                   Válido
# 2                   Válido
# 3                   Válido
# 5                   Válido

# %%
#Verificar que no haya valores faltantes en la columna "Cargo".
valores_faltantes = valoresFaltantes(datos2_df)

print(valores_faltantes)

if valores_faltantes.any():
    print("Hay valores faltantes en el DataFrame.")
else:
    print("No hay valores faltantes en el DataFrame.")
# Out:
# Nombre                      0
# Edad                        1
# Salario                     0
# cargo                       1
# Fecha Ingreso               0
# Validacion_Salario          0
# Validacion_Fecha Ingreso    0
# dtype: int64
# Hay valores faltantes en el DataFrame.

# %% [markdown]
# # **Parte 2**
#
# El segundo ejercicio de práctica deberás realizar el código usando las bibliotecas en Python para la manipulación de los datos y aplicar la calidad de los datos, pegar la captura de pantalla del resultado y copi ar el código según el escenario.

# %% [markdown]
# **2. Ejercicio de práctica 2.**
# 1. Se requiere validar los datos: Precios de Productos, se tiene una lista de productos con los respectivos precios y se necesita validar que ningún precio sea negativo o nulo.

# %% [markdown]
# Se requiere:
#
# 1. Crear un DataFrame con productos y precios.
# 2. Producto: Producto A, Producto B,Producto C,Producto D.
# 3. Precio:150, -25, 100, None.
# 4. Validar que todos los precios sean mayores o iguales a cero y no nulos.
# 5. Mostrar los productos con precios inválidos.
#
# Resultado esperado: Una tabla que muestra qué productos tienen precios incorrectos.

# %%
#Generamos las listas con los vectores
#Crear un DataFrame con productos y precios.

datos3 = {"Productos": ["Producto A", "Producto B", "Producto C", "Producto D"],
          "Precio": [150, -25, 100, None]}

datos3_df = pd.DataFrame(datos3)

for key in datos3.keys():
    print(key, ":", datos3[key])
# Out:
# Productos : ['Producto A', 'Producto B', 'Producto C', 'Producto D']
# Precio : [150, -25, 100, None]

# %%
#Validar que todos los precios sean mayores o iguales a cero y no nulos.
validacionDatos_Numerico_NN(datos3_df, "Precio")
datos3_df
# Out:
#     Productos  Precio Validacion_NN_Precio
# 0  Producto A   150.0               Válido
# 1  Producto B   -25.0             Inválido
# 2  Producto C   100.0               Válido
# 3  Producto D     NaN             Inválido

# %%
#Mostrar los productos con precios inválidos.
datos3_df[datos3_df['Validacion_NN_Precio'] == 'Inválido']
# Out:
#     Productos  Precio Validacion_NN_Precio
# 1  Producto B   -25.0             Inválido
# 3  Producto D     NaN             Inválido

# %% [markdown]
# 2. Se requiere validar los datos duplicados: Clientes en una Base de Datos, se tiene una lista de clientes donde algunos registros tienen el mismo ID y
# necesitas identificarlos.

# %% [markdown]
# Se requiere:
# 1. Crear un DataFrame con información de clientes.
# 2. ID Cliente:1, 2, 3, 2, 4.
# 3. Nombre: Ana, Luis, María, Luis, Carlos
# 4. Verificar si hay duplicados en la columna de ID del cliente.
# 5. Mostrar los registros duplicados.
#
#
# Resultado esperado: Una tabla que contiene solo los clientes que tienen el mismo ID, facilitando su corrección.

# %%
#Generamos las listas con los vectores
#Crear un DataFrame con información de clientes.

datos4 = {"Nombres": ["Ana", "Luis", "María", "Luis", "Carlos"],
          "ID Cliente": [1, 2, 3, 2, 4]}

datos4_df = pd.DataFrame(datos4)

for key in datos4.keys():
    print(key, ":", datos4[key])
# Out:
# Nombres : ['Ana', 'Luis', 'María', 'Luis', 'Carlos']
# ID Cliente : [1, 2, 3, 2, 4]

# %%
#Verificar si hay duplicados en la columna de ID del cliente.
datos4_df[datos4_df.duplicated(subset='ID Cliente')]
# Out:
#   Nombres  ID Cliente
# 3    Luis           2

# %% [markdown]
# 3. Se requiere tener seguridad en los datos: Encriptación y Desencriptación de Datos Sensibles, se tiene un número de tarjeta de crédito que deseas encriptar para protegerlo y luego desencriptarlo para el uso.

# %% [markdown]
# Se requiere:
#
# 1. Crear una cadena con datos sensibles (un número de tarjeta 1234-5678-9101-1121).
# 2. Encriptar esos datos utilizando una clave generada.
# 3. Desencriptar los datos y mostrar ambos (encriptado y desencriptado).
#
#
# Resultado esperado: Ver el número de tarjeta encriptado y luego desencriptado, demostrando cómo proteger la información sensible.

# %%
# Ejemplo 3: Encriptación de datos sensibles (seguridad de los datos)
# Generar clave de encriptación
key = Fernet.generate_key()
print("La clave generada es: ", key)
cipher_suite = Fernet(key)

# Datos sensibles (ej. número de tarjeta)
datos_sensibles = "1234-5678-9101-1121".encode()
print("Los datos sensibles son: ", datos_sensibles)

# Encriptar datos
datos_encriptados = cipher_suite.encrypt(datos_sensibles)
print("Los datos encriptados son: ", datos_encriptados)
# Desencriptar datos
datos_desencriptados = cipher_suite.decrypt(datos_encriptados)
print("Los datos desencriptados son: ", datos_desencriptados.decode())
# Out:
# La clave generada es:  b't4skJ6ZVJqvSfrBowYgLioQDS8tHTBsb2UOJ2Ys7m08='
# Los datos sensibles son:  b'1234-5678-9101-1121'
# Los datos encriptados son:  b'gAAAAABnNYcrbosKhGtF7u4koN4pCZtRapMJWwY_OKqsQcamvtVihZGMhzwHdsjDzLZUpmWLQXTZVLPeFkv1GuFUfmlCWAgo41i6Ysm7Z0I9dcviBj1debs='
# Los datos desencriptados son:  1234-5678-9101-1121
