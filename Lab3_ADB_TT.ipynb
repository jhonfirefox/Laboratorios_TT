# %% [markdown]
# <a href="https://colab.research.google.com/github/jhonfirefox/Laboratorios_TT/blob/main/Lab3_ADB_TT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Se importan las librerias necesarias para los codigos
import pandas as pd
import numpy as np
from cryptography.fernet import Fernet
import datetime

# %%
#Definimos algunas funciones que se utilizaran con frecuencia
def validacionDatos_Numerico(datos, campo):
  datos['Validacion_'+campo] = datos[campo].apply(lambda x:'Válido' if (pd.notnull(x) and (isinstance(x, int) or isinstance(x, float))) else 'Inválido')

#Funcion para validar que los datos sean no negativos
def validacionDatos_Numerico_NN(datos, campo):
  datos['Validacion_NN_'+campo] = datos[campo].apply(lambda x:'Válido' if (pd.notnull(x) and (isinstance(x, int) or isinstance(x, float)) and x >= 0) else 'Inválido')

def valoresFaltantes(datos):
    return datos.isnull().sum()

##Corregimos la fecha de los registros que estan en formato "%Y/%m/%d"
def corregir_fecha(fecha_str, formato):
    try:
        fecha = datetime.datetime.strptime(fecha_str, formato)
        return fecha.strftime("%Y-%m-%d")
    except ValueError:
        return fecha_str

def validarFecha(fecha_str, formato):
    try:
        fecha = datetime.datetime.strptime(fecha_str, formato)
        return "Válido"
    except ValueError:
        return "Inválido"
def eliminarFechasNulas(datos, campo):
  for indice, fecha in enumerate(datos[campo]):
    if pd.isnull(fecha):
      datos = datos.drop(indice)
  return datos

#Validamos que el campo de la fecha se encuentre correcto
def validacionDatos_Fecha(datos, campo, formatoFecha):
   #datos['Validacion'+campo] = datos[campo].apply(lambda x:'Válido' if isinstance(datetime.datetime.strptime(x, "%Y/%m/%d"), datetime.datetime) else 'Inválido')
   datos['Validacion_'+campo] = datos[campo].apply(validarFecha, args=(formatoFecha,))

# %%
#Extraemos los datos del archivo CSV de GitHub
#url  = "https://raw.githubusercontent.com/jhonfirefox/Laboratorios_TT/main/Lab1_DA.csv""
url = "https://raw.githubusercontent.com/jhonfirefox/Laboratorios_TT/main/CSV_Laboratorio3_AD_B.csv"
datos1_df = pd.read_csv(url, sep=",", decimal=".", encoding='windows-1252')
datos1_df
# Out:
#     ID     Name    Category         City  Value        Date
# 0    1  Charlie       Cat C      Chicago   46.0   4/13/2023
# 1    2     Jane       Cat C      Houston   53.0  12/15/2023
# 2    3     Jane  category a      Chicago   68.0   9/28/2023
# 3    4     John         NaN     New York   97.0   4/17/2023
# 4    5     Jane       Cat C      Houston   71.0   3/13/2023
# 5    6      Eve  category a  Los Angeles   61.0    7/8/2023
# 6    7     Jane  Category A      Chicago   48.0   1/21/2023
# 7    8      Bob  CATEGORY B     New York   65.0   4/13/2023
# 8    9      Bob  CATEGORY B  Los Angeles    NaN    5/2/2023
# 9   10     Dave  CATEGORY B  Los Angeles   11.0    8/3/2023
# 10  11      Bob       Cat C          NaN   96.0  11/27/2023
# 11  12     Dave  Category A      Houston   10.0   3/29/2023
# 12  13      Bob       Cat C      Chicago   11.0   4/10/2023
# 13  14      Eve         NaN     New York   99.0  12/26/2023
# 14  15    Grace       Cat C          NaN   41.0    6/1/2023
# ...

# %%
#.isnull(), .duplicated(), y .value_counts() sobre la columna “City”.

#Verificamos los datos duplicados
#Verificamos el formato de las fechas

# %%
#valores_Faltantes = datos1_df.isnull().sum()
#Verificamos los datos nulos
valores_Faltantes = valoresFaltantes(datos1_df)
print(valores_Faltantes)

if valores_Faltantes.any():
    print("Hay valores faltantes en el DataFrame.")
else:
    print("No hay valores faltantes en el DataFrame.")
# Out:
# ID           0
# Name         0
# Category    10
# City        15
# Value        2
# Date         0
# dtype: int64
# Hay valores faltantes en el DataFrame.

# %%
#Eliminamos los valores nulos del campo Category and City
datos2_df = datos1_df.dropna()
#datos1_df
#Volvemos a verificar valores faltantes
valoresFaltantes = valoresFaltantes(datos2_df)

print(valores_Faltantes)

if valores_Faltantes.any():
    print("Hay valores faltantes en el DataFrame.")
else:
    print("No hay valores faltantes en el DataFrame.")
# Out:
# ID           0
# Name         0
# Category    10
# City        15
# Value        2
# Date         0
# dtype: int64
# Hay valores faltantes en el DataFrame.

# %%
datos2_df
# Out:
#     ID     Name    Category         City  Value        Date
# 0    1  Charlie       Cat C      Chicago   46.0   4/13/2023
# 1    2     Jane       Cat C      Houston   53.0  12/15/2023
# 2    3     Jane  category a      Chicago   68.0   9/28/2023
# 4    5     Jane       Cat C      Houston   71.0   3/13/2023
# 5    6      Eve  category a  Los Angeles   61.0    7/8/2023
# 6    7     Jane  Category A      Chicago   48.0   1/21/2023
# 7    8      Bob  CATEGORY B     New York   65.0   4/13/2023
# 9   10     Dave  CATEGORY B  Los Angeles   11.0    8/3/2023
# 11  12     Dave  Category A      Houston   10.0   3/29/2023
# 12  13      Bob       Cat C      Chicago   11.0   4/10/2023
# 15  16     Dave  Category A      Houston   64.0   5/11/2023
# 18  19     John  Category A      Houston   79.0   9/15/2023
# 19  20      Bob  Category A      Chicago   25.0  12/10/2023
# 20  21     Jane  CATEGORY B      Houston   68.0  10/21/2023
# 22  23      Bob  Category B      Houston   68.0   10/4/2023
# ...

# %%
#Verificamos datos duplicados
#df1 = df[df.duplicated(keep=False)]
datos2_df.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 11    False
# 12    False
# 15    False
# 18    False
# 19     True
# 20    False
# 22    False
# 23    False
# 24    False
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 36    False
# 37    False
# 39     True
# 42    False
# 43    False
# 44    False
# 46    False
# 47    False
# 48     True
# 49    False
# 51     True
# 52     True
# 55     True
# 56     True
# 59     True
# dtype: bool

# %%
#Eliminamos duplicados
datos3_df = datos2_df.drop_duplicates(keep=False)
datos3_df
# Out:
#     ID     Name    Category         City  Value        Date
# 0    1  Charlie       Cat C      Chicago   46.0   4/13/2023
# 1    2     Jane       Cat C      Houston   53.0  12/15/2023
# 2    3     Jane  category a      Chicago   68.0   9/28/2023
# 4    5     Jane       Cat C      Houston   71.0   3/13/2023
# 5    6      Eve  category a  Los Angeles   61.0    7/8/2023
# 6    7     Jane  Category A      Chicago   48.0   1/21/2023
# 7    8      Bob  CATEGORY B     New York   65.0   4/13/2023
# 9   10     Dave  CATEGORY B  Los Angeles   11.0    8/3/2023
# 11  12     Dave  Category A      Houston   10.0   3/29/2023
# 12  13      Bob       Cat C      Chicago   11.0   4/10/2023
# 15  16     Dave  Category A      Houston   64.0   5/11/2023
# 18  19     John  Category A      Houston   79.0   9/15/2023
# 20  21     Jane  CATEGORY B      Houston   68.0  10/21/2023
# 22  23      Bob  Category B      Houston   68.0   10/4/2023
# 23  24     Jane  Category B      Chicago   99.0   6/10/2023
# ...

# %%
#Verificamos de nuevo los duplicados
datos3_df.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 4     False
# 5     False
# 6     False
# 7     False
# 9     False
# 11    False
# 12    False
# 15    False
# 18    False
# 20    False
# 22    False
# 23    False
# 24    False
# 27    False
# 28    False
# 29    False
# 36    False
# 37    False
# 42    False
# 43    False
# 44    False
# 46    False
# 47    False
# 49    False
# dtype: bool

# %%
datos2_df = datos2_df.drop_duplicates(keep=False)
datos2_df
# Out:
#     ID     Name    Category         City  Value        Date
# 0    1  Charlie       Cat C      Chicago   46.0   4/13/2023
# 1    2     Jane       Cat C      Houston   53.0  12/15/2023
# 2    3     Jane  category a      Chicago   68.0   9/28/2023
# 4    5     Jane       Cat C      Houston   71.0   3/13/2023
# 5    6      Eve  category a  Los Angeles   61.0    7/8/2023
# 6    7     Jane  Category A      Chicago   48.0   1/21/2023
# 7    8      Bob  CATEGORY B     New York   65.0   4/13/2023
# 9   10     Dave  CATEGORY B  Los Angeles   11.0    8/3/2023
# 11  12     Dave  Category A      Houston   10.0   3/29/2023
# 12  13      Bob       Cat C      Chicago   11.0   4/10/2023
# 15  16     Dave  Category A      Houston   64.0   5/11/2023
# 18  19     John  Category A      Houston   79.0   9/15/2023
# 19  20      Bob  Category A      Chicago   25.0  12/10/2023
# 20  21     Jane  CATEGORY B      Houston   68.0  10/21/2023
# 22  23      Bob  Category B      Houston   68.0   10/4/2023
# ...

# %%
#Contamos el numero de ciudades presentes en el dataset
datos2_df['City'].value_counts()
# Out:
# City
# Chicago        13
# Houston        11
# New York        7
# Los Angeles     6
# Name: count, dtype: int64

# %%
#Contamos el numero de categorias presentes en el dataset
number_cat = datos2_df['Category'].value_counts()
number_cat
# Out:
# Category
# Category A    12
# Category B     9
# Cat C          6
# category a     4
# CATEGORY B     4
# Cat-C          2
# Name: count, dtype: int64

# %%
#Las categorias las dejaremos con el siguiente formato
#Categoria A = CA
#Categoria B = CB
#Categoria C = CC
list_cat = number_cat.index.tolist()
list_cat

for value in list_cat:
  if value == list_cat[0]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CA')
  elif value == list_cat[1]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CB')
  elif value == list_cat[2]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CC')
  elif value == list_cat[3]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CA')
  elif value == list_cat[4]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CB')
  elif value == list_cat[5]:
    datos2_df['Category'] = datos2_df['Category'].replace(value, 'CC')

datos2_df
# Out:
# <ipython-input-23-5c9e13a0527d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos2_df['Category'] = datos2_df['Category'].replace(value, 'CA')
# <ipython-input-23-5c9e13a0527d>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos2_df['Category'] = datos2_df['Category'].replace(value, 'CB')
# <ipython-input-23-5c9e13a0527d>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Estandarizamos la fecha al formato
validacionDatos_Fecha(datos2_df, "Date", "%Y-%m-%d")

datos2_df
# Out:
# <ipython-input-2-80eebb94865f>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Validacion_'+campo] = datos[campo].apply(validarFecha, args=(formatoFecha,))
#     ID     Name Category         City  Value        Date Validacion_Date
# 0    1  Charlie       CC      Chicago   46.0   4/13/2023        Inválido
# 1    2     Jane       CC      Houston   53.0  12/15/2023        Inválido
# 2    3     Jane       CA      Chicago   68.0   9/28/2023        Inválido
# 4    5     Jane       CC      Houston   71.0   3/13/2023        Inválido
# 5    6      Eve       CA  Los Angeles   61.0    7/8/2023        Inválido
# 6    7     Jane       CA      Chicago   48.0   1/21/2023        Inválido
# ...

# %%
##Corregimos la fecha del campo Date en el formato "%Y/%m/%d"

datos2_df['Date'] = datos2_df['Date'].apply(corregir_fecha, args=("%d/%m/%Y",))
datos2_df['Date'] = datos2_df['Date'].apply(corregir_fecha, args=("%m/%d/%Y",))
datos2_df
# Out:
# <ipython-input-32-6b41f9c4f3dd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos2_df['Date'] = datos2_df['Date'].apply(corregir_fecha, args=("%d/%m/%Y",))
# <ipython-input-32-6b41f9c4f3dd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos2_df['Date'] = datos2_df['Date'].apply(corregir_fecha, args=("%m/%d/%Y",))
#     ID     Name Category         City  Value        Date Validacion_Date
# 0    1  Charlie       CC      Chicago   46.0  2023-04-13        Inválido
# ...

# %%
#Validamos de nuevo las fechas
#Estandarizamos la fecha al formato
validacionDatos_Fecha(datos2_df, "Date", "%Y-%m-%d")

datos2_df
# Out:
# <ipython-input-2-80eebb94865f>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['Validacion_'+campo] = datos[campo].apply(validarFecha, args=(formatoFecha,))
#     ID     Name Category         City  Value        Date Validacion_Date
# 0    1  Charlie       CC      Chicago   46.0  2023-04-13          Válido
# 1    2     Jane       CC      Houston   53.0  2023-12-15          Válido
# 2    3     Jane       CA      Chicago   68.0  2023-09-28          Válido
# 4    5     Jane       CC      Houston   71.0  2023-03-13          Válido
# 5    6      Eve       CA  Los Angeles   61.0  2023-08-07          Válido
# 6    7     Jane       CA      Chicago   48.0  2023-01-21          Válido
# ...

# %%
#Generamos una columna con el formato de las fechas correcto
datos2_df['Fecha'] = pd.to_datetime(datos2_df['Date'], errors='coerce', format='%Y-%m-%d')
datos2_df
# Out:
# <ipython-input-34-51661ee4f873>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos2_df['Fecha'] = pd.to_datetime(datos2_df['Date'], errors='coerce', format='%Y-%m-%d')
#     ID     Name Category         City  Value        Date Validacion_Date  \
# 0    1  Charlie       CC      Chicago   46.0  2023-04-13          Válido
# 1    2     Jane       CC      Houston   53.0  2023-12-15          Válido
# 2    3     Jane       CA      Chicago   68.0  2023-09-28          Válido
# 4    5     Jane       CC      Houston   71.0  2023-03-13          Válido
# 5    6      Eve       CA  Los Angeles   61.0  2023-08-07          Válido
# 6    7     Jane       CA      Chicago   48.0  2023-01-21          Válido
# ...

# %%
#Finalmente exportamos el dataset con los datos correctos y limpios
datos2_df.to_csv('datos_limpios.csv', index=False)
